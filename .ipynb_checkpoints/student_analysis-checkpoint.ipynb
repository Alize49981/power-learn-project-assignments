# %% [markdown]
# print("hello ! world")

# %%
# My Analysis
This is my first notebook
# Out:
#   Cell In[3], line 2
#     This is my first notebook
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
data = {
    "Name": ["Ali", "John", "Mary", "Amina", "David"],
    "Math": [80, 70, 90, 60, 85],
    "English": [75, 65, 88, 70, 80],
    "Science": [85, 60, 95, 65, 90]
}

df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       1 data = {
#       2     "Name": ["Ali", "John", "Mary", "Amina", "David"],
#       3     "Math": [80, 70, 90, 60, 85],
#       4     "English": [75, 65, 88, 70, 80],
#       5     "Science": [85, 60, 95, 65, 90]
#       6 }
# ----> 8 df = pd.DataFrame(data)
#       9 df
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "Name": ["Ali", "John", "Mary", "Amina", "David"],
    "Math": [80, 70, 90, 60, 85],
    "English": [75, 65, 88, 70, 80],
    "Science": [85, 60, 95, 65, 90]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Math  English  Science
# 0    Ali    80       75       85
# 1   John    70       65       60
# 2   Mary    90       88       95
# 3  Amina    60       70       65
# 4  David    85       80       90

# %%
df["Total"] = df["Math"] + df["English"] + df["Science"]
df
# Out:
#     Name  Math  English  Science  Total
# 0    Ali    80       75       85    240
# 1   John    70       65       60    195
# 2   Mary    90       88       95    273
# 3  Amina    60       70       65    195
# 4  David    85       80       90    255

# %%
df.describe()
# Out:
#             Math    English    Science       Total
# count   5.000000   5.000000   5.000000    5.000000
# mean   77.000000  75.600000  79.000000  231.600000
# std    12.041595   8.905055  15.572412   35.394915
# min    60.000000  65.000000  60.000000  195.000000
# 25%    70.000000  70.000000  65.000000  195.000000
# 50%    80.000000  75.000000  85.000000  240.000000
# 75%    85.000000  80.000000  90.000000  255.000000
# max    90.000000  88.000000  95.000000  273.000000

# %%
plt.bar(df["Name"], df["Total"])
plt.title("Student Scores")
plt.show()
